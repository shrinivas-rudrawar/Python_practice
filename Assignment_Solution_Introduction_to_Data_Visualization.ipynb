# %% [markdown]
# <a href="https://colab.research.google.com/github/shrinivas-rudrawar/Python_practice/blob/shrinivas/Assignment_Solution_Introduction_to_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <u> Use only those concepts which have been taught till now </u>

# %% [markdown]
# ## Use the file company_sales_data.csv

# %%
import numpy as np
import pandas as pd

from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # <u>**Problem 1**</u>
#
# ### Plot the total profit across the months
#
# * X label name = Month Number
# * Y label name = Total profit

# %%
df=pd.read_csv('/content/drive/My Drive/AlmaBetter/Cohort Aravali/Module 1/Week 4/Day 3/dat/company_sales_data.csv')
df.head()
# Out:
#     month_number  facecream  facewash  ...  moisturizer  total_units  total_profit
# 7              8       3700      1400  ...         1400        36140        361400
# 8              9       3540      1780  ...         1780        23400        234000
# 9             10       1990      1890  ...         1890        26670        266700
# 10            11       2340      2100  ...         2100        41280        412800
# 11            12       2900      1760  ...         1760        30020        300200
#
# [5 rows x 9 columns]

# %%
# Your code here
x_label=df['month_number']                                                      # Month Numbers as X labels
y_label=df['total_profit']                                                      # total Profit Made

plt.plot(x_label,y_label,'ro-', linewidth=2, markersize=8)                                  # red line with 0 as markeer
plt.title('Monthly Profit of  company',{'fontsize':12,'fontweight':30})
plt.ylabel('Total  Profit',{'fontsize':10,'fontweight':15})
plt.xlabel('Month Number',{'fontsize':10,'fontweight':15})
plt.rcParams['figure.figsize'] = (8, 8)                                         # Size of graph

# %% [markdown]
# # <b><u>Problem 2 </u></b>
#
# ### Read face cream and facewash product sales data and show it using the bar chart. The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %%
# Your code here
# Create the figure object
ax = df.groupby(['month_number'])[['facewash','facecream']].mean().plot.bar(
    width=0.8,                                                                  # SETTING LINED EDGES TO CLEAR DETECRIONOF BARS
    linewidth=1,
    edgecolor='black',
    figsize = (12,6),
    fontsize = 10,
)

ax.set_title("Face Cream and Facewash Product Sales Month Wise", fontsize = 20)

# Set x and y-labels
ax.set_xlabel("Month Number", fontsize = 15)
ax.set_ylabel("Product Sales", fontsize = 15)
# Out:
# Text(0, 0.5, 'Product Sales')

# %% [markdown]
# # <b><u>Problem 3</u></b>
#
# ### Display the number of units sold per month for each product using multiline plots. (i.e. separate plotline for each product ).

# %%
# Your code here

all_products=df.loc[:,['facecream','facewash','toothpaste','bathingsoap','shampoo','month_number','moisturizer']]

# SETTING THE MONTH NUMBERS AS THE INDEX
all_products=all_products.set_index('month_number')

# PLOTTING ALL THE PLODUCTS
plt.plot(all_products['facecream'],'ro-', linewidth=2, markersize=5)
plt.plot(all_products['facewash'],'bo-', linewidth=2, markersize=4)
plt.plot(all_products['toothpaste'],'go--', linewidth=2, markersize=4)
plt.plot(all_products['bathingsoap'],'yo-', linewidth=2, markersize=4)
plt.plot(all_products['shampoo'],color='black',marker='o', linewidth=2, markersize=4)
plt.plot(all_products['moisturizer'],'o-', linewidth=2, markersize=4)

#TITTLE
plt.title("Products Sales Month Wise", fontsize = 20)

#aLL THE LEGENDS
plt.legend(['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer'])

# Set x and y-labels
plt.xlabel("Month Number", fontsize = 15)
plt.ylabel("Product Sales", fontsize = 15)

#FIGURE SIZE
plt.rcParams['figure.figsize'] = (10, 8)
