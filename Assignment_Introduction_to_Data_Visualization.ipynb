# %% [markdown]
# <a href="https://colab.research.google.com/github/shrinivas-rudrawar/Python_practice/blob/shrinivas/Assignment_Introduction_to_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <u> Use only those concepts which have been taught till now </u>

# %% [markdown]
# ## Use the file company_sales_data.csv

# %%
import numpy as np
import pandas as pd

from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # <u>**Problem 1**</u>
#
# ### Plot the total profit across the months
#
# * X label name = Month Number
# * Y label name = Total profit

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Your code here
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dat/company_sales_data.csv')
monthly_profit = df.groupby(['month_number'])['total_profit'].sum()
plt.plot(monthly_profit)

plt.title('Monthly profit')
plt.xlabel('Months')
plt.ylabel('Profit')
# df
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# # <b><u>Problem 2 </u></b>
#
# ### Read face cream and facewash product sales data and show it using the bar chart. The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %%
# Your code here
faceCream = df['facecream'].tolist()
faceWash = df['facewash'].tolist()
months = df['month_number'].values

fig, ax = plt.subplots()
ax.bar(months-0.125, faceCream, width=0.25, label='Face Cream Sales Data')
ax.bar(months+ 0.125, faceWash, width=0.25,  label='Face Wash Sales Data')


plt.show()

# %% [markdown]
# # <b><u>Problem 3</u></b>
#
# ### Display the number of units sold per month for each product using multiline plots. (i.e. separate plotline for each product ).

# %%
# Your code here

df1 = pd.DataFrame({'month_number' : df['month_number'], 'facecream' : df['facecream'],  'facewash' : df['facewash'], 'toothpaste' : df['toothpaste'],
                    'bathingsoap' : df['bathingsoap'], 'shampoo' : df['shampoo'], 'moisturizer' : df['moisturizer']})
df1.set_index('month_number', inplace=True)
df1.plot()
plt.title('Productwise Monthly sales data')
plt.xlabel('Month')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')
